# %%
import requests
import csv

headers = {'cookie':'_zap=85d31450-e4ce-4c4b-8c26-93208c8c18fb; d_c0="AFDjFMXhHw-PTusbfxleo5IDODrkssT_lx4=|1552617596"; _xsrf=DvLEqpyauibahhup9OGOqD9iZY8TqWDj; z_c0="2|1:0|10:1553267465|4:z_c0|92:Mi4xdzBQZ0FnQUFBQUFBVU9NVXhlRWZEeVlBQUFCZ0FsVk5DVW1DWFFCY214MlJVX2FUa19HWWM4SktoWktjWVN5aDh3|18ba2b9015f2c6c30c975f3443216879ef98737a7d6416b529adb38bdf624c72"; __gads=ID=ccffbd11fc0d8cd7:T=1553433834:S=ALNI_MaXM-d78o0neH9kOzaIHxEzT57rlQ; q_c1=106fc7b9672c4a5ea5bfa5930fd6406a|1566628601000|1553267467000; tst=r; tgw_l7_route=73af20938a97f63d9b695ad561c4c10c',
          'user-agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'}
url = 'https://www.zhihu.com/api/v3/feed/topstory/recommend?session_token=b11fcc753c5d500cc83f211ba6ae71dd&desktop=true&page_number=2&limit=6&action=down&after_id='

with open(r'E:\python\Crossincode.v1\Zhihu_hotline.csv','w', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['id', 'offset', 'author_name', 'voteup_count', 'thanks_count', 'comment_count'])

for id in range(1,100,6):
    url_m = url+str(id)
    req = requests.get(url_m, headers = headers)
    content = req.json()
    data = content['data']
    fin_data = []
    for d in data:
        try:
            hotline_data = []
            hotline_data.append(d['id'])
            hotline_data.append(d['offset'])
            hotline_data.append(d['target']['author']['name'])
            hotline_data.append(d['target']['voteup_count'])
            hotline_data.append(d['target']['thanks_count'])
            hotline_data.append(d['target']['comment_count'])
            print(hotline_data)
        except Exception as e:
            print(e)
        else:
            fin_data.append(hotline_data)
            print('sucess',hotline_data[1])
    with open(r'E:\python\Crossincode.v1\Zhihu_hotline.csv','a+', encoding='utf-8') as f:
        writer = csv.writer(f)
        for i in fin_data:
            writer.writerow(i)
# Out:
# ['2_1567697120.983', 2, '磅礴科技', 10256, 9792, 142]
# sucess 2
# ['3_1567697120.263', 3, '逆旅行人', 2261, 140, 423]
# sucess 3
# ['4_1567697120.627', 4, '猫猫爱软件', 493, 223, 20]
# sucess 4
# ['5_1567697120.785', 5, '巴洛克有一只兔', 32362, 19334, 390]
# sucess 5
# ['6_1567697120.71', 6, '冯起升', 3025, 1499, 105]
# sucess 6
# ['7_1567697120.148', 7, '雾岛残月', 7036, 3753, 530]
# sucess 7
# ['8_1567697120.119', 8, 'H同学', 5586, 147, 197]
# sucess 8
# ['9_1567697120.959', 9, '肥猫家的猫', 145, 27, 110]
# sucess 9
# ['10_1567697120.844', 10, '唐芊芊', 1004, 527, 22]
# sucess 10
# ['11_1567697120.415', 11, '匿名用户', 19025, 1796, 1088]
# sucess 11
# 'thanks_count'
# ['13_1567697120.851', 13, 'OniOn', 2336, 198, 540]
# sucess 13
# ['14_1567697121.748', 14, '楚虽三户', 1630, 58, 141]
# sucess 14
# ['15_1567697121.243', 15, '方正', 509, 174, 20]
# sucess 15
# ['16_1567697121.38', 16, '团长', 397, 201, 54]
# sucess 16
# ['17_1567697121.145', 17, '蜗牛学院', 14, 1, 8]
# sucess 17
# ['18_1567697121.978', 18, '彭余生x', 20402, 11089, 249]
# ...
